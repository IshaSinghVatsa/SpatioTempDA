# %% [markdown]
# <a href="https://colab.research.google.com/github/IshaSinghVatsa/SpatioTempDA/blob/main/Lab2_STDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
series = pd.read_csv('/content/BRIGHTNESS_SORTED.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)
print(type(series))
display(series.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           longitude  brightness  scan  track    acq_date  acq_time confidence  \
# latitude
# 36.88094   31.35661       367.0  0.32   0.54  2021-07-28      1011        low
# 36.91619   31.50486       367.0  0.13   0.37  2021-07-29      1134       high
# 36.87008   31.62774       367.0  0.13   0.37  2021-07-29      1134       high
# 36.20307   33.27919       367.0  0.55   0.51  2021-07-29        11       high
# 36.83450   31.56425       367.0  0.43   0.46  2021-07-29        11       high
#
#           bright_t31     frp   daynight
# latitude
# 36.88094      362.57    0.00   Daytime
# 36.91619      356.15   72.86   Daytime
# 36.87008      335.66  127.47   Daytime
# 36.20307      339.81   74.01  Nighttime
# 36.83450      335.83   73.82  Nighttime

# %%
series.tail(7)
# Out:
#           longitude  brightness  scan  track    acq_date  acq_time confidence  \
# latitude
# 39.94395   40.58085      295.20  0.46   0.39  2021-07-25      2324    nominal
# 36.85857   36.76656      248.16  0.13   0.36  2021-07-29      1134        low
# 37.34141   35.43962      207.93  0.13   0.36  2021-07-29      1134        low
# 37.35529   35.44639      207.93  0.34   0.56  2021-07-29       952        low
# 36.88261   31.33787      207.93  0.13   0.36  2021-07-28      1151        low
# 36.87680   31.33450      207.93  0.13   0.36  2021-07-28      1151        low
# 36.88347   31.33913      207.93  0.13   0.36  2021-07-28      1151        low
#
#           bright_t31     frp   daynight
# latitude
# 39.94395      284.50    0.70  Nighttime
# 36.85857      320.02   99.62   Daytime
# 37.34141      324.31  103.35   Daytime
# 37.35529      317.17  384.96   Daytime
# 36.88261      320.33  130.35   Daytime
# 36.87680      319.04   83.21   Daytime
# 36.88347      319.74  158.43   Daytime

# %%
series.describe()
# Out:
#          longitude   brightness         scan        track     acq_time  \
# count  4575.000000  4575.000000  4575.000000  4575.000000  4575.000000
# mean     32.814253   335.235296     0.349281     0.425316  1285.968087
# std       3.437819    21.535803     0.295250     0.445194   885.767210
# min      26.241440   207.930000    -2.270000    -4.140000     0.000000
# 25%      31.389775   314.825000     0.170000     0.370000   934.000000
# 50%      31.615110   337.300000     0.410000     0.410000  1134.000000
# 75%      35.446330   351.580000     0.480000     0.550000  2312.000000
# max      44.205090   367.000000     0.790000     0.780000  2354.000000
#
#         bright_t31          frp
# count  4575.000000  4575.000000
# mean    305.562160    21.742345
# std      12.440716    49.219116
# min     271.600000     0.000000
# 25%     296.600000     2.470000
# 50%     304.360000     6.830000
# 75%     311.380000    19.980000
# max     377.540000   987.810000

# %%
import numpy as np
print("maximum of bright_t31 is ",max(series['bright_t31']))
print("minimum of bright_t31 is ",min(series['bright_t31']))
# Out:
# maximum of bright_t31 is  377.54
# minimum of bright_t31 is  271.6

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(series['acq_date'],series['daynight'],'k--',linewidth=3)
plt.xticks(rotation=90)
plt.legend(loc='best')
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
